# %% [markdown]
# ## Quality Estimation for Machine/Human Translation (Unsupervised Approach)
#
# **Author:** Jessica Silva
#
# **Keywords:** Quality Estimation; Machine Translation; Word-level; Sentence-level
#
# **Date:** 20/07/2020

# %% [markdown]
# ## SUMMARY <a class="tocSkip">

# %% [markdown]
# ### Context <a class="tocSkip">

# %% [markdown]
# The aim of this research is to understand and evaluate the quality estimation task for machine/human translation. The goal of this task is to assess the quality of a translation without access to reference translations.

# %% [markdown]
# ### Questions <a class="tocSkip">

# %% [markdown]
# 1) Which strategies can be used for measuring quality of translations? In which cases can they be applied?
#
# 2) Which kind of data and how much data is necessary to train this approaches?
#
# 3) Gains with the new approach.

# %% [markdown]
# ### Main Outcomes (on going) <a class="tocSkip">

# %% [markdown]
# 1) Which strategies can be used for measuring quality of machine translations? In which cases can they be applied?
#
# -
#
# 2) Which kind of data and how much data is necessary to train this approaches?
#
# -
#
# 3) Gains with the new approach.
#
# -

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc">
# 	<ul class="toc-item">
# 		<li>
# 			<span><a href="#Problem-Statement" data-toc-modified-id="Problem-Statement-1">
# 				<span class="toc-item-num">1&nbsp;&nbsp;</span>Problem Statement</a>
# 			</span>
# 		</li>
# 		<li>
# 			<span><a href="#Experimental-Setup" data-toc-modified-id="Experimental-Setup-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Experimental Setup</a></span>
# 		</li>
# 		<li>
# 			<span><a href="#Multilingual-sentence-embeddings" data-toc-modified-id="Multilingual Sentence Embeddings-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Multilingual Sentence Embeddings</a></span>
# 			<ul class="toc-item">
# 				<li>
# 					<span><a href="#Results" data-toc-modified-id="Results-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Dataset</a></span>
# 				</li>
#                 <li>
# 					<span><a href="#TrainPredict" data-toc-modified-id="TrainPredict-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Train and Predict</a></span>
# 				</li>
#                 <li>
#                     <span><a href="#Evaluation" data-toc-modified-id="Evaluation-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Evaluation</a></span>
#                 </li>
# 			</ul>
# 		</li>
# 		<li>
# 			<span><a href="#Benchmarks" data-toc-modified-id="Benchmarks-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Benchmarks</a></span>
# 		</li>
# 		<li>
# 			<span><a href="#Future-Work" data-toc-modified-id="Future-Work-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Future Work</a></span>
# 		</li>
# 	</ul>
# </div>

# %% [markdown]
# ## 1 - Problem Statement
# The aim of this research is to understand and evaluate the quality estimation task for machine/human translation. The goal of this task is to assess the quality of a translation without access to reference translations.

# %% [markdown]
# ## 2 - Experimental Setup
#
# Before being able to run Quality Estimation Tutorial, there is a small setup required. Please check the README.md before continue

# %% [markdown]
# # 3 - Multilingual Sentence Embeddings

# %% [markdown]
# The Multilingual Sentence Embeddings resource can measure the quality in the sentence level:
#
# * **Sentence-level**:
# The goal of the Sentence-level QE task using multilingual sentence embeddings is to predict the quality of the whole translated sentence, based on the semantic similarity score between two sentences in different languages.
#
# ### Architecture
#
# **Sentence Transformer - Knowledge Distillation approach**
#
# The architecture consists of two models, the **Teacher** and the **Student**. The Teacher model produces sentence embeddings from source language. Using translated sentences, the Student model needs to mimic the teacher and generate sentence embeddings in the target language. This training will produce an alignment of vector spaces (source and target) making it possible to measure the cosine distance between them.
#
# This models works with transfer learning and needs to be initialize with some pretrained language models as **BERT**, **GPT 2 or 3**, **XLM**, **XLNet**, **RoBERTa** and so on. We follow the [Paper](https://arxiv.org/abs/2004.09813) and kept **SBERT (english model)** initializing the teacher model and **XLM-R (multilingual model with 100 languages)** initializing the student model.
#
# Some features:
#
# * allows to create multilingual versions from previously monolingual models
#
# * an easy and efficient method to extend existing sentence embedding models to new languages
#
# * the training is based on the idea that a translated sentence should be mapped to the same location in the vector space as the original sentence
#
# <img src='images/knowledge-distillation.png' width='700'>

# %% [markdown]
# ## 4.1 - Dataset

# %% [markdown]
# The Sentence Transformer is trained to learn multilingual sentence embeddings and can be fine-tunned to learn a specific task.
#
# ### Sentence Transformer data without fine-tuning
#
# * **Format**: ( _src, tgt_ )
#
# _src: Sentences in the source language_
#
# _tgt: Translated sentences in the target language_
#
# * **tags**: _no tags (raw data)_
#
# ### Sentence Transformer data with fine-tuning
#
# The fine-tuning can be done in the Semantic Textual Similarity task, with a parallel dataset annotated with semantic similarity scores:
#
# * **Format**: ( _src, tgt_ )
#
# _src: Sentences in the source language_
#
# _tgt: Translated sentences in the target language_
#
# * **tags**: _semantic similarity score_

# %% [markdown]
# ## 4.2 - Train and Predict

# %%
import os
import logging

import torch
import pandas as pd
from ipywidgets import interact, fixed, Textarea
from sentence_transformers import SentenceTransformer, util, evaluation, LoggingHandler

from src import utils
# Out:
# [nltk_data] Downloading package punkt to /home/jessica/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Here we will load a public pretrained student model that was extended with 13 languages.
#
# **distiluse-base-multilingual-cased**: Supported languages: Arabic, Chinese, Dutch, English, French, German, Italian, Korean, Polish, Portuguese, Russian, Spanish, Turkish. Model is based on DistilBERT-multi-lingual.

# %%
model = SentenceTransformer('distiluse-base-multilingual-cased')

# %% [markdown]
# Calculating the cosine distance between sentences:

# %%
source = ['Eric has 22']
source_embedding = model.encode(source, convert_to_tensor=True)

# %%
target = ['Eric ha 22']
target_embedding = model.encode(target, convert_to_tensor=True)

# %%
score = util.pytorch_cos_sim(source_embedding, target_embedding)[0]
print("(Score: %.4f)" % (score))
# Out:
# (Score: 0.9576)

# %% [markdown]
# Interactive demo:

# %%
SOURCE = Textarea(value=source[0], layout={'width': '90%'})
TARGET = Textarea(value=target[0], layout={'width': '90%'})
_interact = interact(utils.SentenceTransformerViz, model=fixed(model), source=SOURCE, target=TARGET)
# Out:
# interactive(children=(Textarea(value='Eric has 22', description='source', layout=Layout(width='90%')), Textare…

# %% [markdown]
# ### Adding a new language
#
# Here we extended a new student model with 3 similar languages: Spanish, European-Portuguese and Brazilian-Portuguese. The difference to the previous model is the addition of the EN-Brazilian-Portuguese parallel dataset (413,689 sentences).
#
# For initialization, we still kept SBERT (english model) as a teacher model and XLM-R (multilingual model with 100 languages) as a student model.
#
# You should download the trained model folder [here](https://definedcrowd-my.sharepoint.com/:u:/p/jessica_silva/ETITnnE5olxPpzh-5_iAwRgBA2T4H2pFLqVi_ijF2r5ESA?e=r1fslp) and extract it on `models/`.

# %%
new_model = SentenceTransformer('../models/trained_model-en-es-pt-ptbr')

# %%
SOURCE = Textarea(layout={'width': '90%'})
TARGET = Textarea(layout={'width': '90%'})
_interact = interact(utils.SentenceTransformerViz, model=fixed(new_model), source=SOURCE, target=TARGET)
# Out:
# Score: <span style='color:green'>1.0000 </span>

# %% [markdown]
# ## 4.3 - Evaluation

# %% [markdown]
# ### Translation Retrieval

# %% [markdown]
# One way to assess the quality of our model is through a Translation Retrieval task. We can use a parallel testset and perform a target search from the source, using the cosine distance.

# %% [markdown]
# Loading the model
#
# Supported languages: **Arabic, Chinese, Dutch, English, French, German, Italian, Korean, Polish, Portuguese, Russian, Spanish, Turkish**.

# %%
logging.basicConfig(format='%(asctime)s - %(message)s',
                    datefmt='%Y-%m-%d %H:%M:%S',
                    level=logging.INFO,
                    handlers=[LoggingHandler()])

# %%
model = "distiluse-base-multilingual-cased"
inference_batch_size = 32

model = SentenceTransformer(model)

# %% [markdown]
# ### Test Data (Quality Inspection)
#
# The testset used is parallel data from Apple, coming from the Quality Inspection stage made by DefinedCrowd. So far, we have parallel data in the following languages: **english-arabic (en-ar), english-italian (en-it), english-japanese (en-jp), english-korean (en-ko), english-russian (en-ru) and russian-french (ru-fr)**.

# %%
def get_data(language_pair):
    path = "../data/processed/" + language_pair + "/"
    src_file = pd.read_csv(path + 'source.txt', delimiter="\n", header=None, encoding='utf-8', engine='python')
    trg_file = pd.read_csv(path + 'target.txt', delimiter="\n", header=None, encoding='utf-8', engine='python')
    gold_file = pd.read_csv(path + 'gold.txt', delimiter="\n", header=None, encoding='utf-8', engine='python')

    src_sentences = src_file[0].tolist()
    trg_sentences = trg_file[0].tolist()
    gold_sentences = gold_file[0].tolist()

    return src_sentences, trg_sentences, gold_sentences

# %% [markdown]
# For each sentence pair, we check if they have the shortest cosine distance between source embedding and target embedding. To do this, for each src_sentences[i] we check if trg_sentences[j] has the highest similarity out of all target sentences. If this is the case, we have a hit, otherwise an error. This evaluator reports accuracy (higher = better).

# %%
src_sentences, trg_sentences, gold_sentences = get_data("en-ko")
logging.info(str(len(src_sentences))+" sentence pairs")
dev_trans_acc = evaluation.TranslationEvaluator(src_sentences, trg_sentences, batch_size=inference_batch_size, print_wrong_matches=True)
dev_trans_acc(model)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-bd807fbee05c> in <module>
# ----> 1 src_sentences, trg_sentences, gold_sentences = get_data("en-ko")
#       2 logging.info(str(len(src_sentences))+" sentence pairs")
#       3 dev_trans_acc = evaluation.TranslationEvaluator(src_sentences, trg_sentences, batch_size=inference_batch_size, print_wrong_matches=True)
#       4 dev_trans_acc(model)
#
# <ipython-input-9-24696a0bd5fe> in get_data(language_pair)
#       1 def get_data(language_pair):
#       2     path = "../data/processed/" + language_pair + "/"
# ----> 3     src_file = pd.read_csv(path + 'source.txt', delimiter="\n", header=None, encoding='utf-8', engine='python')
#       4     trg_file = pd.read_csv(path + 'target.txt', delimiter="\n", header=None, encoding='utf-8', engine='python')
#       5     gold_file = pd.read_csv(path + 'gold.txt', delimiter="\n", header=None, encoding='utf-8', engine='python')
#
# ~/projects/NLP.MachineTranslation.QualityEstimationAPI/venv/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/projects/NLP.MachineTranslation.QualityEstimationAPI/venv/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/projects/NLP.MachineTranslation.QualityEstimationAPI/venv/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# ~/projects/NLP.MachineTranslation.QualityEstimationAPI/venv/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1177                     'are "c", "python", or "python-fwf")'
#    1178                 )
# -> 1179             self._engine = klass(self.f, **self.options)
#    1180
#    1181     def _failover_to_python(self):
#
# ~/projects/NLP.MachineTranslation.QualityEstimationAPI/venv/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, **kwds)
#    2370         self._comment_lines = []
#    2371
# -> 2372         f, handles = get_handle(
#    2373             f,
#    2374             "r",
#
# ~/projects/NLP.MachineTranslation.QualityEstimationAPI/venv/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/processed/en-ko/source.txt'

# %% [markdown]
# <img src='images/translation-retriveal-evaluation.png' width='700'>

# %% [markdown]
# ### Semantic similarity score
#
# Another way to assess the quality of our model is checking if the cosine distance between the source and the target is lower than the source and the gold target (Post-edited by humans).

# %% [markdown]
# Convert the source, target and gold to embeddings and calculate the cosine distance between the pairs.

# %%
scores = []
scores_gold = []
src_sentences, trg_sentences, gold_sentences = get_data('en-it')
for src_sentence, trg_sentence, gold_sentence in zip(src_sentences, trg_sentences, gold_sentences):
    source_embedding = model.encode(src_sentence, convert_to_tensor=True)
    target_embedding = model.encode(trg_sentence, convert_to_tensor=True)
    gold_embedding = model.encode(gold_sentence, convert_to_tensor=True)
    scores.append(util.pytorch_cos_sim(source_embedding, target_embedding)[0])
    scores_gold.append(util.pytorch_cos_sim(source_embedding, gold_embedding)[0])

# %% [markdown]
# For each source and target pair, we check if they have a lower cosine distance than source and gold target (post-edited by humans). To do this: cosine_distance(src_sentences[i] and trg_sentences[i]) <= cosine_distance(src_sentences[i] and gold_trg_sentences[i]). If this is the case, we have a hit, otherwise an error. This evaluator reports accuracy (higher = better).

# %%
results = zip(range(len(scores)), scores, scores_gold)
results = sorted(results, key=lambda x: x[1], reverse=False)

correct_score = 0
for idx, score, score_gold in results:
    if score_gold >= score:
        correct_score += 1

    print('Source: ', src_sentences[idx])
    print('Target: ', trg_sentences[idx])
    print('Gold: ', gold_sentences[idx])
    print("(Score: %.4f)" % (score))
    print("(Score Gold: %.4f)" % (score_gold))
    print("*******************************************************************************************")

acc_score = correct_score / len(results)
logging.info(str(len(results)) + " sentence pairs")
logging.info("Accuracy: {:.2f}".format(acc_score * 100))
# Out:
# Source:  Do you want to have a desert
# Target:  Gradiresti un dessert?
# Gold:  Vuoi avere un deserto?
# (Score: 0.3461)
# (Score Gold: 0.8793)
# *******************************************************************************************
# Source:  Do you want to have a desert
# Target:  Gradiresti un dessert?
# Gold:  Vuoi avere un deserto?
# (Score: 0.3461)
# (Score Gold: 0.8793)
# *******************************************************************************************
# Source:  Do you want to have a desert
# Target:  Gradiresti un dessert?
# Gold:  Vuoi avere un deserto?
# (Score: 0.3461)
# (Score Gold: 0.8793)
# *******************************************************************************************
# Source:  Do you want to have a desert
# Target:  Gradiresti un dessert?
# Gold:  Vuoi avere un deserto?
# (Score: 0.3461)
# (Score Gold: 0.8793)
# *******************************************************************************************
# Source:  Source Text
# Target:  Target Text
# Gold:  Suggested Target Text
# (Score: 0.5344)
# (Score Gold: 0.4671)
# *******************************************************************************************
# Source:  Source Text
# Target:  Target Text
# Gold:  Suggested Target Text
# (Score: 0.5344)
# (Score Gold: 0.4671)
# *******************************************************************************************
# Source:  Source Text
# Target:  Target Text
# Gold:  Suggested Target Text
# (Score: 0.5344)
# (Score Gold: 0.4671)
# *******************************************************************************************
# Source:  Source Text
# Target:  Target Text
# Gold:  Suggested Target Text
# (Score: 0.5344)
# (Score Gold: 0.4671)
# *******************************************************************************************
# Source:  I've seen cast iron pans that are very expensive they don't work so good and I have seen cheap ones that work very very good if you are doing the curing process from the beginning right
# Target:  Ho visto pentole in ghisa molto costose non funzionano così bene e ne ho viste di economiche che vanno molto molto bene se si effettua in modo corretto la cura dall'inizio
# Gold:  Ho visto padelle in ghisa molto costose che non funzionano così bene e ne ho viste di economiche che vanno molto molto bene se si effettua in modo corretto la cura dall'inizio
# (Score: 0.5791)
# (Score Gold: 0.6429)
# *******************************************************************************************
# Source:  I've seen cast iron pans that are very expensive they don't work so good and I have seen cheap ones that work very very good if you are doing the curing process from the beginning right
# Target:  Ho visto pentole in ghisa molto costose non funzionano così bene e ne ho viste di economiche che vanno molto molto bene se si effettua in modo corretto la cura dall'inizio
# Gold:  Ho visto padelle in ghisa molto costose che non funzionano così bene e ne ho viste di economiche che vanno molto molto bene se si effettua in modo corretto la cura dall'inizio
# (Score: 0.5791)
# (Score Gold: 0.6429)
# *******************************************************************************************
# Source:  I've seen cast iron pans that are very expensive they don't work so good and I have seen cheap ones that work very very good if you are doing the curing process from the beginning right
# Target:  Ho visto pentole in ghisa molto costose non funzionano così bene e ne ho viste di economiche che vanno molto molto bene se si effettua in modo corretto la cura dall'inizio
# Gold:  Ho visto padelle in ghisa molto costose che non funzionano così bene e ne ho viste di economiche che vanno molto molto bene se si effettua in modo corretto la cura dall'inizio
# (Score: 0.5791)
# (Score Gold: 0.6429)
# *******************************************************************************************
# Source:  I've seen cast iron pans that are very expensive they don't work so good and I have seen cheap ones that work very very good if you are doing the curing process from the beginning right
# Target:  Ho visto pentole in ghisa molto costose non funzionano così bene e ne ho viste di economiche che vanno molto molto bene se si effettua in modo corretto la cura dall'inizio
# Gold:  Ho visto padelle in ghisa molto costose che non funzionano così bene e ne ho viste di economiche che vanno molto molto bene se si effettua in modo corretto la cura dall'inizio
# (Score: 0.5791)
# (Score Gold: 0.6429)
# *******************************************************************************************
# Source:  Or something then I am sure you like this with you right now I'm not sure
# Target:  O qualcosa poi è certo che ti piacerà subito non è certo
# Gold:  O qualcosa che poi sono certo che ti piacerà, al momento non ne sono certo
# (Score: 0.5956)
# (Score Gold: 0.6987)
# *******************************************************************************************
# Source:  Or something then I am sure you like this with you right now I'm not sure
# Target:  O qualcosa poi è certo che ti piacerà subito non è certo
# Gold:  O qualcosa che poi sono certo che ti piacerà, al momento non ne sono certo
# (Score: 0.5956)
# (Score Gold: 0.6987)
# *******************************************************************************************
# Source:  Or something then I am sure you like this with you right now I'm not sure
# Target:  O qualcosa poi è certo che ti piacerà subito non è certo
# Gold:  O qualcosa che poi sono certo che ti piacerà, al momento non ne sono certo
# (Score: 0.5956)
# (Score Gold: 0.6987)
# *******************************************************************************************
# Source:  Or something then I am sure you like this with you right now I'm not sure
# Target:  O qualcosa poi è certo che ti piacerà subito non è certo
# Gold:  O qualcosa che poi sono certo che ti piacerà, al momento non ne sono certo
# (Score: 0.5956)
# (Score Gold: 0.6987)
# *******************************************************************************************
# Source:  I'm not very good at German but I am trying my best
# Target:  Non ne la cavo tanto bene con il tedesco, ma ce la sto mettendo tutta
# Gold:  Non me la cavo tanto bene con il tedesco, ma ce la sto mettendo tutta
# (Score: 0.6408)
# (Score Gold: 0.6568)
# *******************************************************************************************
# Source:  I'm not very good at German but I am trying my best
# Target:  Non ne la cavo tanto bene con il tedesco, ma ce la sto mettendo tutta
# Gold:  Non me la cavo tanto bene con il tedesco, ma ce la sto mettendo tutta
# (Score: 0.6408)
# (Score Gold: 0.6568)
# *******************************************************************************************
# Source:  I'm not very good at German but I am trying my best
# Target:  Non ne la cavo tanto bene con il tedesco, ma ce la sto mettendo tutta
# Gold:  Non me la cavo tanto bene con il tedesco, ma ce la sto mettendo tutta
# (Score: 0.6408)
# (Score Gold: 0.6568)
# *******************************************************************************************
# Source:  I'm not very good at German but I am trying my best
# Target:  Non ne la cavo tanto bene con il tedesco, ma ce la sto mettendo tutta
# Gold:  Non me la cavo tanto bene con il tedesco, ma ce la sto mettendo tutta
# (Score: 0.6408)
# (Score Gold: 0.6568)
# *******************************************************************************************
# Source:  No wear something cool
# Target:  No metterti qualcosa di figo
# Gold:  Non metterti qualcosa di figo
# (Score: 0.6500)
# (Score Gold: 0.6545)
# *******************************************************************************************
# Source:  No wear something cool
# Target:  No metterti qualcosa di figo
# Gold:  Non metterti qualcosa di figo
# (Score: 0.6500)
# (Score Gold: 0.6545)
# *******************************************************************************************
# Source:  No wear something cool
# Target:  No metterti qualcosa di figo
# Gold:  Non metterti qualcosa di figo
# (Score: 0.6500)
# (Score Gold: 0.6545)
# *******************************************************************************************
# Source:  No wear something cool
# Target:  No metterti qualcosa di figo
# Gold:  Non metterti qualcosa di figo
# (Score: 0.6500)
# (Score Gold: 0.6545)
# *******************************************************************************************
# Source:  Yes we can prepare the branches in the morning
# Target:  Si possiamo preparare  dei brunch per il mattino
# Gold:  Sì, possiamo preparare  i rami la mattina
# (Score: 0.7159)
# (Score Gold: 0.8571)
# *******************************************************************************************
# Source:  Yes we can prepare the branches in the morning
# Target:  Si possiamo preparare  dei brunch per il mattino
# Gold:  Sì, possiamo preparare  i rami la mattina
# (Score: 0.7159)
# (Score Gold: 0.8571)
# *******************************************************************************************
# Source:  Yes we can prepare the branches in the morning
# Target:  Si possiamo preparare  dei brunch per il mattino
# Gold:  Sì, possiamo preparare  i rami la mattina
# (Score: 0.7159)
# (Score Gold: 0.8571)
# *******************************************************************************************
# Source:  Yes we can prepare the branches in the morning
# Target:  Si possiamo preparare  dei brunch per il mattino
# Gold:  Sì, possiamo preparare  i rami la mattina
# (Score: 0.7159)
# (Score Gold: 0.8571)
# *******************************************************************************************
# Source:  Okay do you feel like you've only been here a week
# Target:  Senti come se fossi qui da una settimana?
# Gold:  Ok, ti senti come se fossi qui solamente da una settimana?
# (Score: 0.7200)
# (Score Gold: 0.8266)
# *******************************************************************************************
# Source:  Okay do you feel like you've only been here a week
# Target:  Senti come se fossi qui da una settimana?
# Gold:  Ok, ti senti come se fossi qui solamente da una settimana?
# (Score: 0.7200)
# (Score Gold: 0.8266)
# *******************************************************************************************
# Source:  Okay do you feel like you've only been here a week
# Target:  Senti come se fossi qui da una settimana?
# Gold:  Ok, ti senti come se fossi qui solamente da una settimana?
# (Score: 0.7200)
# (Score Gold: 0.8266)
# *******************************************************************************************
# Source:  Okay do you feel like you've only been here a week
# Target:  Senti come se fossi qui da una settimana?
# Gold:  Ok, ti senti come se fossi qui solamente da una settimana?
# (Score: 0.7200)
# (Score Gold: 0.8266)
# *******************************************************************************************
# Source:  I can let her sleep for another 10 minutes but then I have to drive away because I have another appointment at another location
# Target:  Posso lasciare che dormi per altri 10 minuti ma poi devo andare via perché ho un altro appuntamento in un altro posto
# Gold:  Posso lasciare che dorma per altri 10 minuti ma poi devo andare via perché ho un altro appuntamento in un altro posto
# (Score: 0.7204)
# (Score Gold: 0.7287)
# *******************************************************************************************
# Source:  I can let her sleep for another 10 minutes but then I have to drive away because I have another appointment at another location
# Target:  Posso lasciare che dormi per altri 10 minuti ma poi devo andare via perché ho un altro appuntamento in un altro posto
# Gold:  Posso lasciare che dorma per altri 10 minuti ma poi devo andare via perché ho un altro appuntamento in un altro posto
# (Score: 0.7204)
# (Score Gold: 0.7287)
# *******************************************************************************************
# Source:  I can let her sleep for another 10 minutes but then I have to drive away because I have another appointment at another location
# Target:  Posso lasciare che dormi per altri 10 minuti ma poi devo andare via perché ho un altro appuntamento in un altro posto
# Gold:  Posso lasciare che dorma per altri 10 minuti ma poi devo andare via perché ho un altro appuntamento in un altro posto
# (Score: 0.7204)
# (Score Gold: 0.7287)
# *******************************************************************************************
# Source:  I can let her sleep for another 10 minutes but then I have to drive away because I have another appointment at another location
# Target:  Posso lasciare che dormi per altri 10 minuti ma poi devo andare via perché ho un altro appuntamento in un altro posto
# Gold:  Posso lasciare che dorma per altri 10 minuti ma poi devo andare via perché ho un altro appuntamento in un altro posto
# (Score: 0.7204)
# (Score Gold: 0.7287)
# *******************************************************************************************
# Source:  Good morning is real happiness and good morning majesty
# Target:  Buongiorno è vera felicità buongiorno sua maestà
# Gold:  Buongiorno è vera felicità e buongiorno sua maestà
# (Score: 0.7499)
# (Score Gold: 0.7956)
# *******************************************************************************************
# Source:  Good morning is real happiness and good morning majesty
# Target:  Buongiorno è vera felicità buongiorno sua maestà
# Gold:  Buongiorno è vera felicità e buongiorno sua maestà
# (Score: 0.7499)
# (Score Gold: 0.7956)
# *******************************************************************************************
# Source:  Good morning is real happiness and good morning majesty
# Target:  Buongiorno è vera felicità buongiorno sua maestà
# Gold:  Buongiorno è vera felicità e buongiorno sua maestà
# (Score: 0.7499)
# (Score Gold: 0.7956)
# *******************************************************************************************
# Source:  Good morning is real happiness and good morning majesty
# Target:  Buongiorno è vera felicità buongiorno sua maestà
# Gold:  Buongiorno è vera felicità e buongiorno sua maestà
# (Score: 0.7499)
# (Score Gold: 0.7956)
# *******************************************************************************************
# Source:  I do not do weight training as I was really tired
# Target:  Non faccio sollevamento pesi perché sento tanta stanchezza
# Gold:  Non faccio sollevamento pesi perché mi sento molto stanco
# (Score: 0.7591)
# (Score Gold: 0.7597)
# *******************************************************************************************
# Source:  I do not do weight training as I was really tired
# Target:  Non faccio sollevamento pesi perché sento tanta stanchezza
# Gold:  Non faccio sollevamento pesi perché mi sento molto stanco
# (Score: 0.7591)
# (Score Gold: 0.7597)
# *******************************************************************************************
# Source:  I do not do weight training as I was really tired
# Target:  Non faccio sollevamento pesi perché sento tanta stanchezza
# Gold:  Non faccio sollevamento pesi perché mi sento molto stanco
# (Score: 0.7591)
# (Score Gold: 0.7597)
# *******************************************************************************************
# Source:  I do not do weight training as I was really tired
# Target:  Non faccio sollevamento pesi perché sento tanta stanchezza
# Gold:  Non faccio sollevamento pesi perché mi sento molto stanco
# (Score: 0.7591)
# (Score Gold: 0.7597)
# *******************************************************************************************
# Source:  My favourite programme on TV is the Discovery Channel
# Target:  Il mio canale preferito in TV è Disceveri Channel
# Gold:  Il mio canale preferito in TV è Discovery Channel
# (Score: 0.7790)
# (Score Gold: 0.9017)
# *******************************************************************************************
# Source:  My favourite programme on TV is the Discovery Channel
# Target:  Il mio canale preferito in TV è Disceveri Channel
# Gold:  Il mio canale preferito in TV è Discovery Channel
# (Score: 0.7790)
# (Score Gold: 0.9017)
# *******************************************************************************************
# Source:  My favourite programme on TV is the Discovery Channel
# Target:  Il mio canale preferito in TV è Disceveri Channel
# Gold:  Il mio canale preferito in TV è Discovery Channel
# (Score: 0.7790)
# (Score Gold: 0.9017)
# *******************************************************************************************
# Source:  My favourite programme on TV is the Discovery Channel
# Target:  Il mio canale preferito in TV è Disceveri Channel
# Gold:  Il mio canale preferito in TV è Discovery Channel
# (Score: 0.7790)
# (Score Gold: 0.9017)
# *******************************************************************************************
# Source:  And come back cos there'll be more ass shaking when you do
# Target:  E ritorna perché ci sarà più agitazione di culo quando lo fai
# Gold:  E ritorna perché ci sarà più scuotimento di culo quando lo fai
# (Score: 0.7864)
# (Score Gold: 0.7532)
# *******************************************************************************************
# Source:  And come back cos there'll be more ass shaking when you do
# Target:  E ritorna perché ci sarà più agitazione di culo quando lo fai
# Gold:  E ritorna perché ci sarà più scuotimento di culo quando lo fai
# (Score: 0.7864)
# (Score Gold: 0.7532)
# *******************************************************************************************
# Source:  And come back cos there'll be more ass shaking when you do
# Target:  E ritorna perché ci sarà più agitazione di culo quando lo fai
# Gold:  E ritorna perché ci sarà più scuotimento di culo quando lo fai
# (Score: 0.7864)
# (Score Gold: 0.7532)
# *******************************************************************************************
# Source:  And come back cos there'll be more ass shaking when you do
# Target:  E ritorna perché ci sarà più agitazione di culo quando lo fai
# Gold:  E ritorna perché ci sarà più scuotimento di culo quando lo fai
# (Score: 0.7864)
# (Score Gold: 0.7532)
# *******************************************************************************************
# Source:  Hi Mr. Flo how do you do as a template because I do not know how
# Target:  Ciao Mr Flo come va come modello perché io non so come
# Gold:  Ciao Mr Flo come fai a fare il modello perché io non so come farlo
# (Score: 0.8115)
# (Score Gold: 0.8713)
# *******************************************************************************************
# Source:  Hi Mr. Flo how do you do as a template because I do not know how
# Target:  Ciao Mr Flo come va come modello perché io non so come
# Gold:  Ciao Mr Flo come fai a fare il modello perché io non so come farlo
# (Score: 0.8115)
# (Score Gold: 0.8713)
# *******************************************************************************************
# Source:  Hi Mr. Flo how do you do as a template because I do not know how
# Target:  Ciao Mr Flo come va come modello perché io non so come
# Gold:  Ciao Mr Flo come fai a fare il modello perché io non so come farlo
# (Score: 0.8115)
# (Score Gold: 0.8713)
# *******************************************************************************************
# Source:  Hi Mr. Flo how do you do as a template because I do not know how
# Target:  Ciao Mr Flo come va come modello perché io non so come
# Gold:  Ciao Mr Flo come fai a fare il modello perché io non so come farlo
# (Score: 0.8115)
# (Score Gold: 0.8713)
# *******************************************************************************************
# Source:  Really mean what I just said
# Target:  Significa davvero quello che ho appena detto
# Gold:  Intendevo davvero quello che ho appena detto
# (Score: 0.8182)
# (Score Gold: 0.8752)
# *******************************************************************************************
# Source:  Really mean what I just said
# Target:  Significa davvero quello che ho appena detto
# Gold:  Intendevo davvero quello che ho appena detto
# (Score: 0.8182)
# (Score Gold: 0.8752)
# *******************************************************************************************
# Source:  Really mean what I just said
# Target:  Significa davvero quello che ho appena detto
# Gold:  Intendevo davvero quello che ho appena detto
# (Score: 0.8182)
# (Score Gold: 0.8752)
# *******************************************************************************************
# Source:  Really mean what I just said
# Target:  Significa davvero quello che ho appena detto
# Gold:  Intendevo davvero quello che ho appena detto
# (Score: 0.8182)
# (Score Gold: 0.8752)
# *******************************************************************************************
# Source:  It attacks at the onset religious fanaticism which it considers a pathological element implanted in the human brain by despotism
# Target:  Attacca il sano fanatismo religioso che considera essere un elemento patologico inculcato nel cervello umano con dispotismo
# Gold:  Attacca l'insorgenza del fanatismo religioso, che considera essere un elemento patologico inculcato nel cervello umano dal dispotismo
# (Score: 0.8239)
# (Score Gold: 0.8651)
# *******************************************************************************************
# Source:  It attacks at the onset religious fanaticism which it considers a pathological element implanted in the human brain by despotism
# Target:  Attacca il sano fanatismo religioso che considera essere un elemento patologico inculcato nel cervello umano con dispotismo
# Gold:  Attacca l'insorgenza del fanatismo religioso, che considera essere un elemento patologico inculcato nel cervello umano dal dispotismo
# (Score: 0.8239)
# (Score Gold: 0.8651)
# *******************************************************************************************
# Source:  It attacks at the onset religious fanaticism which it considers a pathological element implanted in the human brain by despotism
# Target:  Attacca il sano fanatismo religioso che considera essere un elemento patologico inculcato nel cervello umano con dispotismo
# Gold:  Attacca l'insorgenza del fanatismo religioso, che considera essere un elemento patologico inculcato nel cervello umano dal dispotismo
# (Score: 0.8239)
# (Score Gold: 0.8651)
# *******************************************************************************************
# Source:  It attacks at the onset religious fanaticism which it considers a pathological element implanted in the human brain by despotism
# Target:  Attacca il sano fanatismo religioso che considera essere un elemento patologico inculcato nel cervello umano con dispotismo
# Gold:  Attacca l'insorgenza del fanatismo religioso, che considera essere un elemento patologico inculcato nel cervello umano dal dispotismo
# (Score: 0.8239)
# (Score Gold: 0.8651)
# *******************************************************************************************
# Source:  What time the train finish
# Target:  A che ore finisce il treno?
# Gold:  A che ora arriva il treno?
# (Score: 0.8574)
# (Score Gold: 0.7993)
# *******************************************************************************************
# Source:  What time the train finish
# Target:  A che ore finisce il treno?
# Gold:  A che ora arriva il treno?
# (Score: 0.8574)
# (Score Gold: 0.7993)
# *******************************************************************************************
# Source:  What time the train finish
# Target:  A che ore finisce il treno?
# Gold:  A che ora arriva il treno?
# (Score: 0.8574)
# (Score Gold: 0.7993)
# *******************************************************************************************
# Source:  What time the train finish
# Target:  A che ore finisce il treno?
# Gold:  A che ora arriva il treno?
# (Score: 0.8574)
# (Score Gold: 0.7993)
# *******************************************************************************************
# Source:  Eric has 22
# Target:  Eric ha 22 anni
# Gold:  Eric ha 22
# (Score: 0.8739)
# (Score Gold: 0.9576)
# *******************************************************************************************
# Source:  Eric has 22
# Target:  Eric ha 22 anni
# Gold:  Eric ha 22
# (Score: 0.8739)
# (Score Gold: 0.9576)
# *******************************************************************************************
# Source:  Eric has 22
# Target:  Eric ha 22 anni
# Gold:  Eric ha 22
# (Score: 0.8739)
# (Score Gold: 0.9576)
# *******************************************************************************************
# Source:  Eric has 22
# Target:  Eric ha 22 anni
# Gold:  Eric ha 22
# (Score: 0.8739)
# (Score Gold: 0.9576)
# *******************************************************************************************
# Source:  Under the program European poor groups map out the shelter needs in their communities and can access infrastructure subsidies and housing loans to upgrade their homes
# Target:  Nel programma Gruppi Poveri Europei il tracciamento del rifugio è necessario nelle loro comunità e può accedere ai sussidi per le infrastrutture e prestiti alla costruzione per aggiornare le loro case
# Gold:  Nell'ambito del programma, i gruppi poveri europei tracciano le esigenze di accoglienza nelle loro comunità e possono accedere ai sussidi per le infrastrutture e ai prestiti abitativi per migliorare le loro case
# (Score: 0.8752)
# (Score Gold: 0.9133)
# *******************************************************************************************
# Source:  Under the program European poor groups map out the shelter needs in their communities and can access infrastructure subsidies and housing loans to upgrade their homes
# Target:  Nel programma Gruppi Poveri Europei il tracciamento del rifugio è necessario nelle loro comunità e può accedere ai sussidi per le infrastrutture e prestiti alla costruzione per aggiornare le loro case
# Gold:  Nell'ambito del programma, i gruppi poveri europei tracciano le esigenze di accoglienza nelle loro comunità e possono accedere ai sussidi per le infrastrutture e ai prestiti abitativi per migliorare le loro case
# (Score: 0.8752)
# (Score Gold: 0.9133)
# *******************************************************************************************
# Source:  Under the program European poor groups map out the shelter needs in their communities and can access infrastructure subsidies and housing loans to upgrade their homes
# Target:  Nel programma Gruppi Poveri Europei il tracciamento del rifugio è necessario nelle loro comunità e può accedere ai sussidi per le infrastrutture e prestiti alla costruzione per aggiornare le loro case
# Gold:  Nell'ambito del programma, i gruppi poveri europei tracciano le esigenze di accoglienza nelle loro comunità e possono accedere ai sussidi per le infrastrutture e ai prestiti abitativi per migliorare le loro case
# (Score: 0.8752)
# (Score Gold: 0.9133)
# *******************************************************************************************
# Source:  Under the program European poor groups map out the shelter needs in their communities and can access infrastructure subsidies and housing loans to upgrade their homes
# Target:  Nel programma Gruppi Poveri Europei il tracciamento del rifugio è necessario nelle loro comunità e può accedere ai sussidi per le infrastrutture e prestiti alla costruzione per aggiornare le loro case
# Gold:  Nell'ambito del programma, i gruppi poveri europei tracciano le esigenze di accoglienza nelle loro comunità e possono accedere ai sussidi per le infrastrutture e ai prestiti abitativi per migliorare le loro case
# (Score: 0.8752)
# (Score Gold: 0.9133)
# *******************************************************************************************
# Source:  1930s 1940s and afterwards these houses become available on the market up for sale people would buy buy them pretty much for the real estate value and then demolish the old house and would have a brand new double storey triple storey home in this spot
# Target:  Negli anni 30 40 e successivamente queste case sono diventate disponibili alla vendita sul mercato le persone le avrebbero comprate pagando quasi il loro reale valore immobiliare e poi avrebbero demolito la vecchia casa e avrebbero avuta una nuovissima casa sue due o tre piani in quest'area
# Gold:  Negli anni '30, '40 e successivamente queste case sono diventate disponibili alla vendita sul mercato, le persone le avrebbero comprate soprattutto per il loro valore immobiliare e poi avrebbero demolito la vecchia casa e avrebbero avuto una nuovissima casa su due o tre piani in quest'area
# (Score: 0.8801)
# (Score Gold: 0.8810)
# *******************************************************************************************
# Source:  1930s 1940s and afterwards these houses become available on the market up for sale people would buy buy them pretty much for the real estate value and then demolish the old house and would have a brand new double storey triple storey home in this spot
# Target:  Negli anni 30 40 e successivamente queste case sono diventate disponibili alla vendita sul mercato le persone le avrebbero comprate pagando quasi il loro reale valore immobiliare e poi avrebbero demolito la vecchia casa e avrebbero avuta una nuovissima casa sue due o tre piani in quest'area
# Gold:  Negli anni '30, '40 e successivamente queste case sono diventate disponibili alla vendita sul mercato, le persone le avrebbero comprate soprattutto per il loro valore immobiliare e poi avrebbero demolito la vecchia casa e avrebbero avuto una nuovissima casa su due o tre piani in quest'area
# (Score: 0.8801)
# (Score Gold: 0.8810)
# *******************************************************************************************
# Source:  1930s 1940s and afterwards these houses become available on the market up for sale people would buy buy them pretty much for the real estate value and then demolish the old house and would have a brand new double storey triple storey home in this spot
# Target:  Negli anni 30 40 e successivamente queste case sono diventate disponibili alla vendita sul mercato le persone le avrebbero comprate pagando quasi il loro reale valore immobiliare e poi avrebbero demolito la vecchia casa e avrebbero avuta una nuovissima casa sue due o tre piani in quest'area
# Gold:  Negli anni '30, '40 e successivamente queste case sono diventate disponibili alla vendita sul mercato, le persone le avrebbero comprate soprattutto per il loro valore immobiliare e poi avrebbero demolito la vecchia casa e avrebbero avuto una nuovissima casa su due o tre piani in quest'area
# (Score: 0.8801)
# (Score Gold: 0.8810)
# *******************************************************************************************
# Source:  1930s 1940s and afterwards these houses become available on the market up for sale people would buy buy them pretty much for the real estate value and then demolish the old house and would have a brand new double storey triple storey home in this spot
# Target:  Negli anni 30 40 e successivamente queste case sono diventate disponibili alla vendita sul mercato le persone le avrebbero comprate pagando quasi il loro reale valore immobiliare e poi avrebbero demolito la vecchia casa e avrebbero avuta una nuovissima casa sue due o tre piani in quest'area
# Gold:  Negli anni '30, '40 e successivamente queste case sono diventate disponibili alla vendita sul mercato, le persone le avrebbero comprate soprattutto per il loro valore immobiliare e poi avrebbero demolito la vecchia casa e avrebbero avuto una nuovissima casa su due o tre piani in quest'area
# (Score: 0.8801)
# (Score Gold: 0.8810)
# *******************************************************************************************
# Source:  Yesterday Veronica came over and left a parcel near the plant I just want to make sure you did pick it up and take it inside that is to give to Lucy so Miguel comes from England he can give it to me please thank you
# Target:  Ieri è passata Veronica e ha lasciato un pacco vicino alla pianta, volevo solo accertarmi che tu l'avessi preso e portato in casa, è da dare a Lucy così Miguel arriva dall'Inghilterra e può darmelo grazie
# Gold:  Ieri è passata Veronica e ha lasciato un pacco vicino alla pianta, volevo solo accertarmi che tu l'avessi preso e portato dentro, è da dare a Lucy così Miguel arriva dall'Inghilterra e può darmelo grazie
# (Score: 0.8932)
# (Score Gold: 0.9052)
# *******************************************************************************************
# Source:  Yesterday Veronica came over and left a parcel near the plant I just want to make sure you did pick it up and take it inside that is to give to Lucy so Miguel comes from England he can give it to me please thank you
# Target:  Ieri è passata Veronica e ha lasciato un pacco vicino alla pianta, volevo solo accertarmi che tu l'avessi preso e portato in casa, è da dare a Lucy così Miguel arriva dall'Inghilterra e può darmelo grazie
# Gold:  Ieri è passata Veronica e ha lasciato un pacco vicino alla pianta, volevo solo accertarmi che tu l'avessi preso e portato dentro, è da dare a Lucy così Miguel arriva dall'Inghilterra e può darmelo grazie
# (Score: 0.8932)
# (Score Gold: 0.9052)
# *******************************************************************************************
# Source:  Yesterday Veronica came over and left a parcel near the plant I just want to make sure you did pick it up and take it inside that is to give to Lucy so Miguel comes from England he can give it to me please thank you
# Target:  Ieri è passata Veronica e ha lasciato un pacco vicino alla pianta, volevo solo accertarmi che tu l'avessi preso e portato in casa, è da dare a Lucy così Miguel arriva dall'Inghilterra e può darmelo grazie
# Gold:  Ieri è passata Veronica e ha lasciato un pacco vicino alla pianta, volevo solo accertarmi che tu l'avessi preso e portato dentro, è da dare a Lucy così Miguel arriva dall'Inghilterra e può darmelo grazie
# (Score: 0.8932)
# (Score Gold: 0.9052)
# *******************************************************************************************
# Source:  Yesterday Veronica came over and left a parcel near the plant I just want to make sure you did pick it up and take it inside that is to give to Lucy so Miguel comes from England he can give it to me please thank you
# Target:  Ieri è passata Veronica e ha lasciato un pacco vicino alla pianta, volevo solo accertarmi che tu l'avessi preso e portato in casa, è da dare a Lucy così Miguel arriva dall'Inghilterra e può darmelo grazie
# Gold:  Ieri è passata Veronica e ha lasciato un pacco vicino alla pianta, volevo solo accertarmi che tu l'avessi preso e portato dentro, è da dare a Lucy così Miguel arriva dall'Inghilterra e può darmelo grazie
# (Score: 0.8932)
# (Score Gold: 0.9052)
# *******************************************************************************************
# Source:  If lost have to be charged 300 back
# Target:  Se lo si perde deve essere ricaricato di 300
# Gold:  Se lo si perde devono essere riaddebitati 300
# (Score: 0.9061)
# (Score Gold: 0.8789)
# *******************************************************************************************
# Source:  If lost have to be charged 300 back
# Target:  Se lo si perde deve essere ricaricato di 300
# Gold:  Se lo si perde devono essere riaddebitati 300
# (Score: 0.9061)
# (Score Gold: 0.8789)
# *******************************************************************************************
# Source:  If lost have to be charged 300 back
# Target:  Se lo si perde deve essere ricaricato di 300
# Gold:  Se lo si perde devono essere riaddebitati 300
# (Score: 0.9061)
# (Score Gold: 0.8789)
# *******************************************************************************************
# Source:  If lost have to be charged 300 back
# Target:  Se lo si perde deve essere ricaricato di 300
# Gold:  Se lo si perde devono essere riaddebitati 300
# (Score: 0.9061)
# (Score Gold: 0.8789)
# *******************************************************************************************
# Source:  But I'm happy I mean before he was very almost like every day drinking but since I'm here I felt like he is less drinking then when I was in Indonesia
# Target:  Ma io sono felice voglio dire prima che lui bevesse quasi come tutti i giorni ma poiché io sono qui mi sentivo come se lui stia bevendo di meno di quando non fossi in Indonesia
# Gold:  Ma io sono felice voglio dire prima che lui bevesse praticamente quasi tutti i giorni ma poiché io sono qui mi sentivo come se lui stesse bevendo di meno di quando non fossi in Indonesia
# (Score: 0.9086)
# (Score Gold: 0.9039)
# *******************************************************************************************
# Source:  But I'm happy I mean before he was very almost like every day drinking but since I'm here I felt like he is less drinking then when I was in Indonesia
# Target:  Ma io sono felice voglio dire prima che lui bevesse quasi come tutti i giorni ma poiché io sono qui mi sentivo come se lui stia bevendo di meno di quando non fossi in Indonesia
# Gold:  Ma io sono felice voglio dire prima che lui bevesse praticamente quasi tutti i giorni ma poiché io sono qui mi sentivo come se lui stesse bevendo di meno di quando non fossi in Indonesia
# (Score: 0.9086)
# (Score Gold: 0.9039)
# *******************************************************************************************
# Source:  But I'm happy I mean before he was very almost like every day drinking but since I'm here I felt like he is less drinking then when I was in Indonesia
# Target:  Ma io sono felice voglio dire prima che lui bevesse quasi come tutti i giorni ma poiché io sono qui mi sentivo come se lui stia bevendo di meno di quando non fossi in Indonesia
# Gold:  Ma io sono felice voglio dire prima che lui bevesse praticamente quasi tutti i giorni ma poiché io sono qui mi sentivo come se lui stesse bevendo di meno di quando non fossi in Indonesia
# (Score: 0.9086)
# (Score Gold: 0.9039)
# *******************************************************************************************
# Source:  But I'm happy I mean before he was very almost like every day drinking but since I'm here I felt like he is less drinking then when I was in Indonesia
# Target:  Ma io sono felice voglio dire prima che lui bevesse quasi come tutti i giorni ma poiché io sono qui mi sentivo come se lui stia bevendo di meno di quando non fossi in Indonesia
# Gold:  Ma io sono felice voglio dire prima che lui bevesse praticamente quasi tutti i giorni ma poiché io sono qui mi sentivo come se lui stesse bevendo di meno di quando non fossi in Indonesia
# (Score: 0.9086)
# (Score Gold: 0.9039)
# *******************************************************************************************
# Source:  We made a reservation for 10 people but only nine people came
# Target:  Abbiamo prenotato per 10 persone ma ne sono venute solo 9
# Gold:  Abbiamo prenotato per 10 persone ma ne sono venute solo nove
# (Score: 0.9489)
# (Score Gold: 0.9529)
# *******************************************************************************************
# Source:  We made a reservation for 10 people but only nine people came
# Target:  Abbiamo prenotato per 10 persone ma ne sono venute solo 9
# Gold:  Abbiamo prenotato per 10 persone ma ne sono venute solo nove
# (Score: 0.9489)
# (Score Gold: 0.9529)
# *******************************************************************************************
# Source:  We made a reservation for 10 people but only nine people came
# Target:  Abbiamo prenotato per 10 persone ma ne sono venute solo 9
# Gold:  Abbiamo prenotato per 10 persone ma ne sono venute solo nove
# (Score: 0.9489)
# (Score Gold: 0.9529)
# *******************************************************************************************
# Source:  We made a reservation for 10 people but only nine people came
# Target:  Abbiamo prenotato per 10 persone ma ne sono venute solo 9
# Gold:  Abbiamo prenotato per 10 persone ma ne sono venute solo nove
# (Score: 0.9489)
# (Score Gold: 0.9529)
# *******************************************************************************************
# Source:  And ski resort next to my home just above 35 minutes
# Target:  E lo ski resort vicino a casa mia è a soli 35 minuti
# Gold:  E la stazione sciistica vicino a casa mia è a soli 35 minuti
# (Score: 0.9503)
# (Score Gold: 0.8471)
# *******************************************************************************************
# Source:  And ski resort next to my home just above 35 minutes
# Target:  E lo ski resort vicino a casa mia è a soli 35 minuti
# Gold:  E la stazione sciistica vicino a casa mia è a soli 35 minuti
# (Score: 0.9503)
# (Score Gold: 0.8471)
# *******************************************************************************************
# Source:  And ski resort next to my home just above 35 minutes
# Target:  E lo ski resort vicino a casa mia è a soli 35 minuti
# Gold:  E la stazione sciistica vicino a casa mia è a soli 35 minuti
# (Score: 0.9503)
# (Score Gold: 0.8471)
# *******************************************************************************************
# Source:  And ski resort next to my home just above 35 minutes
# Target:  E lo ski resort vicino a casa mia è a soli 35 minuti
# Gold:  E la stazione sciistica vicino a casa mia è a soli 35 minuti
# (Score: 0.9503)
# (Score Gold: 0.8471)
# *******************************************************************************************
# Source:  I like working from home because we can watch TV
# Target:  Mi piace lavorare da casa perché possiamo guarda la TV
# Gold:  Mi piace lavorare da casa perché possiamo guardare la TV
# (Score: 0.9670)
# (Score Gold: 0.9668)
# *******************************************************************************************
# Source:  I like working from home because we can watch TV
# Target:  Mi piace lavorare da casa perché possiamo guarda la TV
# Gold:  Mi piace lavorare da casa perché possiamo guardare la TV
# (Score: 0.9670)
# (Score Gold: 0.9668)
# *******************************************************************************************
# Source:  I like working from home because we can watch TV
# Target:  Mi piace lavorare da casa perché possiamo guarda la TV
# Gold:  Mi piace lavorare da casa perché possiamo guardare la TV
# (Score: 0.9670)
# (Score Gold: 0.9668)
# *******************************************************************************************
# Source:  I like working from home because we can watch TV
# Target:  Mi piace lavorare da casa perché possiamo guarda la TV
# Gold:  Mi piace lavorare da casa perché possiamo guardare la TV
# (Score: 0.9670)
# (Score Gold: 0.9668)
# *******************************************************************************************

# %% [markdown]
# <img src='images/semantic-similarity-target-vs-post-editing.png' width='700'>

# %% [markdown]
# ### Test Data (Quality Validation)
#
# The Quality Validation is done on the platform and the crowd member needs to answer three questions:
#
# * The source text is intelligible?
# * Is the meaning of the source conveyed?
# * Is the translation fluent and sound natural in the target language?

# %% [markdown]
# ## Readings
#
# I suggest the following complementary readings on Quality Estimation
#
# * A really good [book](https://www.morganclaypool.com/doi/abs/10.2200/S00854ED1V01Y201805HLT039) of Quality Estimation from Lucia Specia et al.
# * [Predictor-Estimator architecture paper](https://www.aclweb.org/anthology/W17-4763.pdf)
# * The [main conference on Machine Translation](http://www.statmt.org/wmt20/) and the [Quality Estimation](http://www.statmt.org/wmt20/quality-estimation-task.html) shared task.

# %% [markdown]
# ## References

# %% [markdown]
# [1] [Quality Estimation for Machine Translation](https://www.morganclaypool.com/doi/abs/10.2200/S00854ED1V01Y201805HLT039)
#
# [2] [Unsupervised Quality Estimation for Neural Machine Translation](https://arxiv.org/abs/2005.10608)
#
# [3] [Unbabel's Participation in the WMT19 Translation Quality Estimation Shared Task](https://arxiv.org/abs/1907.10352)
#
# [4] [OpenKiwi: An Open Source Framework for Quality Estimation](https://arxiv.org/abs/1902.08646)
#
# [5] [Quality In, Quality Out: Learning from Actual Mistakes](https://fredblain.org/transfer-learning-qe.html)
#
# [6] [Making Monolingual Sentence Embeddings Multilingual using Knowledge Distillation](https://arxiv.org/pdf/2004.09813.pdf)
#
# [7] [Sentence-BERT: Sentence Embeddings using Siamese BERT-Networks](https://arxiv.org/abs/1908.10084)
#
# [8] [Massively Multilingual Sentence Embeddings for Zero-Shot Cross-Lingual Transfer and Beyond](https://arxiv.org/pdf/1812.10464.pdf)
#
# [9] [BERTSCORE: EVALUATING TEXT GENERATION WITH BERT](https://arxiv.org/pdf/1904.09675.pdf)
